# %%
#Ace Realty wants to determine whether the average time it takes to sell homes is different for its two offices.
#A sample of 40 sales from office #1 revealed a mean of 90 days and a standard deviation of 15 days. A sample of 
#50 sales from office #2 revealed a mean of 100 days and a standard deviation of 20 days. Use a .05 level of 
#significance.

# %%
from math import sqrt
from scipy import stats

# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
x1= stats.binom(90, 15, 40)

# %%
x2= stats.binom(100, 20, 50)

# %%
x1

# %%
xbar1 = x1.mean()
xbar2 = x2.mean()



s1 = x1.std()
s2 = x2.std()

# %%
#Load the mpg dataset and use it to answer the following question
from pydataset import data

# %%
mpg = data('mpg')

# %%
mpg
# Out:
#     manufacturer                   model  displ  year  cyl       trans drv  \
# 1           audi                      a4    1.8  1999    4    auto(l5)   f
# 2           audi                      a4    1.8  1999    4  manual(m5)   f
# 3           audi                      a4    2.0  2008    4  manual(m6)   f
# 4           audi                      a4    2.0  2008    4    auto(av)   f
# 5           audi                      a4    2.8  1999    6    auto(l5)   f
# 6           audi                      a4    2.8  1999    6  manual(m5)   f
# 7           audi                      a4    3.1  2008    6    auto(av)   f
# 8           audi              a4 quattro    1.8  1999    4  manual(m5)   4
# 9           audi              a4 quattro    1.8  1999    4    auto(l5)   4
# 10          audi              a4 quattro    2.0  2008    4  manual(m6)   4
# 11          audi              a4 quattro    2.0  2008    4    auto(s6)   4
# ...

# %%
year= mpg.groupby("year")

# %%
mpg[mpg['year']== '2008'].trans
# Out:
# Series([], Name: trans, dtype: object)

# %%
eight
mpg[mpg['year']== '2008'].trans
# Out:
# Series([], Name: cty, dtype: int64)

# %%
stats.ttest_1samp()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-57-6fc10f577959> in <module>
# ----> 1 stats.ttest_1samp()
#
# TypeError: ttest_1samp() missing 2 required positional arguments: 'a' and 'popmean'

# %%
year.hwy.mean()
# Out:
# year
# 1999    23.427350
# 2008    23.452991
# Name: hwy, dtype: float64

# %%
stats.ttest_ind()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-61-f74ed9d602ad> in <module>
# ----> 1 stats.ttest_2samp()
#
# AttributeError: module 'scipy.stats' has no attribute 'ttest_2samp'

# %%
mpg.plot.scatter(x='hwy', y= 'cty')

# %%
x= mpg.hwy
y= mpg.cty

# %%
r, p = stats.pearsonr(x, y)

# %%
mpg.plot.scatter(x = 'displ', y = 'cty')

# %%
#H_o: There is no relationship between displacement and gas milage in the city
#H_a: Ther is a a realtionship between the two

x= mpg.displ
y= mpg.cty

# %%
r, p = stats.pearsonr(x, y)

# %%
print(f'r= {r:.4}')
print(f'p= {p:.4}')
# Out:
# r= -0.7985
# p= 4.738e-53

# %%
from pydataset import data

# %%
data('employees')
# Out:
# Did you mean:
# Employment, Unemployment, Males, eagles, EmplUK, polyps, msleep, movies

# %%
-m pip install mysqlclient pymysql
# Out:
#   File "<ipython-input-99-431ac4be03dc>", line 1
#     -m pip install mysqlclient pymysql
#          ^
# SyntaxError: invalid syntax

# %%
import pydataset
